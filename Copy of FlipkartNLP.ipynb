# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
flipkart=pd.read_csv('https://github.com/sukhioo7/Data-Science/blob/main/Machine%20Learning/NLP%20and%20Naive%20Bayes/Flipkart%20Review.csv?raw=true')

# %%
flipkart.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205052 entries, 0 to 205051
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   product_name   205052 non-null  object
#  1   product_price  205052 non-null  object
#  2   Rate           205052 non-null  object
#  3   Review         180388 non-null  object
#  4   Summary        205041 non-null  object
#  5   Sentiment      205052 non-null  object
# dtypes: object(6)
# memory usage: 9.4+ MB

# %%
flipkart.head()
# Out:
#                                         product_name product_price Rate  \
# 0  Candes 12 L Room/Personal Air Cooler??????(Whi...          3999    5
# 1  Candes 12 L Room/Personal Air Cooler??????(Whi...          3999    5
# 2  Candes 12 L Room/Personal Air Cooler??????(Whi...          3999    3
# 3  Candes 12 L Room/Personal Air Cooler??????(Whi...          3999    1
# 4  Candes 12 L Room/Personal Air Cooler??????(Whi...          3999    3
#
#             Review                                            Summary  \
# 0           super!  great cooler excellent air flow and for this p...
# 1          awesome              best budget 2 fit cooler nice cooling
# 2             fair  the quality is good but the power of air is de...
# 3  useless product                  very bad product its a only a fan
# 4             fair                                      ok ok product
#
#   Sentiment
# 0  positive
# 1  positive
# 2  positive
# 3  negative
# 4   neutral

# %%
flipkart.isnull().sum()
# Out:
# product_name         0
# product_price        0
# Rate                 0
# Review           24664
# Summary             11
# Sentiment            0
# dtype: int64

# %%
flipkart.dropna(inplace=True)
flipkart.reset_index(inplace=True)

# %%
flipkart.drop(['product_name','product_price'],axis=1,inplace=True)

# %%
flipkart.head()
# Out:
#    index Rate           Review  \
# 0      0    5           super!
# 1      1    5          awesome
# 2      2    3             fair
# 3      3    1  useless product
# 4      4    3             fair
#
#                                              Summary Sentiment
# 0  great cooler excellent air flow and for this p...  positive
# 1              best budget 2 fit cooler nice cooling  positive
# 2  the quality is good but the power of air is de...  positive
# 3                  very bad product its a only a fan  negative
# 4                                      ok ok product   neutral

# %%
flipkart['Review']=flipkart['Review'].apply(lambda review: review.replace(' ',''))

# %%
flipkart['Rate']=flipkart['Rate'].apply(lambda rate: [rate])

# %%
flipkart['Review']=flipkart['Review'].apply(lambda review: [review])

# %%
flipkart['Summary'] = flipkart['Summary'].apply(lambda summary: summary.split())

# %%
flipkart.head()
# Out:
#    index Rate            Review  \
# 0      0  [5]          [super!]
# 1      1  [5]         [awesome]
# 2      2  [3]            [fair]
# 3      3  [1]  [uselessproduct]
# 4      4  [3]            [fair]
#
#                                              Summary Sentiment
# 0  [great, cooler, excellent, air, flow, and, for...  positive
# 1      [best, budget, 2, fit, cooler, nice, cooling]  positive
# 2  [the, quality, is, good, but, the, power, of, ...  positive
# 3         [very, bad, product, its, a, only, a, fan]  negative
# 4                                  [ok, ok, product]   neutral

# %%
flipkart['Tag'] = flipkart['Rate'] + flipkart['Review'] + flipkart['Summary']

# %%
flipkart_tag = flipkart[['Tag','Sentiment']]

# %%
flipkart_tag.head()
# Out:
#                                                  Tag Sentiment
# 0  [5, super!, great, cooler, excellent, air, flo...  positive
# 1  [5, awesome, best, budget, 2, fit, cooler, nic...  positive
# 2  [3, fair, the, quality, is, good, but, the, po...  positive
# 3  [1, uselessproduct, very, bad, product, its, a...  negative
# 4                         [3, fair, ok, ok, product]   neutral

# %%
from nltk.stem.porter import PorterStemmer
porter_stem=PorterStemmer()

# %%
def tag_stemming(words):
  temp=[]
  for word in words:
    stemmed_word=porter_stem.stem(word)
    temp.append(stemmed_word)
  return temp

# %%
flipkart_tag['Tag'].apply(tag_stemming)
# Out:
# 0         [5, super!, great, cooler, excel, air, flow, a...
# 1         [5, awesom, best, budget, 2, fit, cooler, nice...
# 2         [3, fair, the, qualiti, is, good, but, the, po...
# 3         [1, uselessproduct, veri, bad, product, it, a,...
# 4                                [3, fair, ok, ok, product]
#                                 ...
# 180374                         [5, mustbuy!, good, product]
# 180375                                    [5, super!, nice]
# 180376           [3, nice, veri, nice, and, fast, deliveri]
# 180377                       [5, justwow!, awesom, product]
# 180378    [4, value-for-money, veri, good, but, mix, bow...
# Name: Tag, Length: 180379, dtype: object

# %%
flipkart_tag['Tag']=flipkart_tag['Tag'].apply(tag_stemming)
# Out:
# <ipython-input-21-954260856bf9>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   flipkart_tag['Tag']=flipkart_tag['Tag'].apply(tag_stemming)

# %%
flipkart_tag['Tag'].apply(lambda tag:' '.join(tag))
# Out:
# 0         5 super! great cooler excel air flow and for t...
# 1               5 awesom best budget 2 fit cooler nice cool
# 2         3 fair the qualiti is good but the power of ai...
# 3         1 uselessproduct veri bad product it a onli a fan
# 4                                      3 fair ok ok product
#                                 ...
# 180374                              5 mustbuy! good product
# 180375                                        5 super! nice
# 180376                   3 nice veri nice and fast deliveri
# 180377                            5 justwow! awesom product
# 180378    4 value-for-money veri good but mix bowl not i...
# Name: Tag, Length: 180379, dtype: object

# %%
flipkart_tag['Tag']=flipkart_tag['Tag'].apply(lambda tag:' '.join(tag))
# Out:
# <ipython-input-23-abbe3d46466e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   flipkart_tag['Tag']=flipkart_tag['Tag'].apply(lambda tag:' '.join(tag))

# %%
flipkart_tag.head()
# Out:
#                                                  Tag Sentiment
# 0  5 super! great cooler excel air flow and for t...  positive
# 1        5 awesom best budget 2 fit cooler nice cool  positive
# 2  3 fair the qualiti is good but the power of ai...  positive
# 3  1 uselessproduct veri bad product it a onli a fan  negative
# 4                               3 fair ok ok product   neutral

# %% [markdown]
# #Applying Count Vectorizer

# %%
from sklearn.feature_extraction.text import CountVectorizer

count_vector = CountVectorizer(max_features=500, stop_words='english')

# %%
count_vector.fit(flipkart_tag['Tag'])
# Out:
# CountVectorizer(max_features=500, stop_words='english')

# %%
CountVectorizer(max_features=500, stop_words='english')
# Out:
# CountVectorizer(max_features=500, stop_words='english')

# %%
arr = count_vector.transform(flipkart_tag['Tag']).toarray()

# %%
arr.shape
# Out:
# (180379, 500)

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,Y_train,Y_test = train_test_split(arr,flipkart_tag['Sentiment'],test_size=0.2,random_state=101)

# %%
from sklearn.naive_bayes import GaussianNB,MultinomialNB

gaussian_nb = GaussianNB()

# %%
multi_nb = MultinomialNB()

# %%
gaussian_nb.fit(X_train,Y_train)
# Out:
# GaussianNB()

# %%
GaussianNB()
# Out:
# GaussianNB()

# %%
multi_nb.fit(X_train,Y_train)
# Out:
# MultinomialNB()

# %%
MultinomialNB()
# Out:
# MultinomialNB()

# %%
predictions_gaussian = gaussian_nb.predict(X_test)

# %%
predictions_multi = multi_nb.predict(X_test)

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
print(classification_report(predictions_gaussian,Y_test))
# Out:
#               precision    recall  f1-score   support
#
#     negative       0.56      0.69      0.62      3987
#      neutral       0.76      0.07      0.13     17954
#     positive       0.47      0.98      0.63     14135
#
#     accuracy                           0.50     36076
#    macro avg       0.60      0.58      0.46     36076
# weighted avg       0.63      0.50      0.38     36076

# %%
print(classification_report(predictions_multi,Y_test))
# Out:
#               precision    recall  f1-score   support
#
#     negative       0.84      0.82      0.83      4989
#      neutral       0.31      0.48      0.38      1113
#     positive       0.97      0.95      0.96     29974
#
#     accuracy                           0.92     36076
#    macro avg       0.70      0.75      0.72     36076
# weighted avg       0.93      0.92      0.92     36076

# %%
import joblib as jb
import numpy as np
import pandas as pd
from nltk.stem.porter import PorterStemmer
import pickle

# %%
model=pickle.dump(gaussian_nb,open('Flipkart_review_model.pkl','wb'))

# %%
model=pickle.load(open('Flipkart_review_model.pkl','rb'))

# %%
count_vector = pickle.dump(count_vector,open('Vector_matrix.pkl','wb'))

# %%
count_vector = pickle.load(open('Vector_matrix.pkl','rb'))

# %%
rate = input('Enter Review Rating : ')
review = input('Enter your review: ')
summary = input('Enter review summary: ')
tag = list(rate) + list(review.replace(' ','')) + summary.split()
# Out:
# Enter Review Rating : 2
# Enter your review: positive
# Enter review summary: your product fucked up

# %%
harry_potter = PorterStemmer()
def stemming_words(items):
  temp_lst = []
  for word in items:
    temp_lst.append(harry_potter.stem(word))
  temp_lst = list(set(temp_lst))
  return temp_lst

# %%
tag = stemming_words(flipkart_tag)

# %%
tag = ' '.join(tag)
flipkart_tag
# Out:
#                                                       Tag Sentiment
# 0       5 super! great cooler excel air flow and for t...  positive
# 1             5 awesom best budget 2 fit cooler nice cool  positive
# 2       3 fair the qualiti is good but the power of ai...  positive
# 3       1 uselessproduct veri bad product it a onli a fan  negative
# 4                                    3 fair ok ok product   neutral
# ...                                                   ...       ...
# 180374                            5 mustbuy! good product  positive
# 180375                                      5 super! nice  positive
# 180376                 3 nice veri nice and fast deliveri  positive
# 180377                          5 justwow! awesom product  positive
# 180378  4 value-for-money veri good but mix bowl not i...   neutral
#
# [180379 rows x 2 columns]

# %%
tag = pd.Series(tag)

# %%
tag
# Out:
# 0    sentiment tag
# dtype: object

# %%
matrix_tag = count_vector.transform(tag).toarray()

# %%
matrix_tag.shape
# Out:
# (1, 500)

# %%
prediction = model.predict(matrix_tag)

# %%
prediction
# Out:
# array(['neutral'], dtype='<U8')
